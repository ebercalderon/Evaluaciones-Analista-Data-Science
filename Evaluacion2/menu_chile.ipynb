# %% [markdown]
# # **Evaluacion 2**

# %%
# IMPORTANDO LIBRERIAS
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
# LEYENDA LA DATA
df = pd.read_csv('menu_chile.csv')
df.head()
# Out:
#        NEGOCIO_N            CLIENTE    LATITUD   LONGITUD     CIUDAD  \
# 0  LOC0753788837  CL002245479930082        NaN        NaN        NaN
# 1  LOC0753788837  CL005946679560035        NaN        NaN        NaN
# 2  LOC0753788837  CL001542979350091        NaN        NaN        NaN
# 3  LOC0753788837  CL000000070000000        NaN        NaN        NaN
# 4  LOC0753788837  CL000627579340080 -41.112242 -73.053861  FRUTILLAR
#
#   ORIGEN_DEL_PEDIDO       NUM_PEDIDO METODO_DE_PAGO  MONTO_TOTAL  DESCUENTO  \
# 0             LOCAL  PED010229633826       EFECTIVO        22650     4000.0
# 1             LOCAL  PED010219666799       EFECTIVO        11800     4000.0
# 2             LOCAL  PED010229649085       EFECTIVO        20700     4000.0
# 3             LOCAL  PED010129642585       EFECTIVO        35000        1.0
# 4          TELEFONO  PED010129640922       EFECTIVO        18550     1000.0
#
#          FECHAHORA_CREA  MEMBRESIA       MENU
# 0  2021-03-12T20:47:57Z          1  CORRIENTE
# ...

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744922 entries, 0 to 744921
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   NEGOCIO_N          744922 non-null  object
#  1   CLIENTE            744922 non-null  object
#  2   LATITUD            371492 non-null  float64
#  3   LONGITUD           371492 non-null  float64
#  4   CIUDAD             371492 non-null  object
#  5   ORIGEN_DEL_PEDIDO  744919 non-null  object
#  6   NUM_PEDIDO         744922 non-null  object
#  7   METODO_DE_PAGO     744922 non-null  object
#  8   MONTO_TOTAL        744922 non-null  int64
#  9   DESCUENTO          744922 non-null  float64
#  10  FECHAHORA_CREA     744922 non-null  object
#  11  MEMBRESIA          744922 non-null  int64
#  12  MENU               744922 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 73.9+ MB
# ...

# %%
# VALORES NULOS POR COLUMNA
df.isnull().sum()
# Out:
# NEGOCIO_N                 0
# CLIENTE                   0
# LATITUD              373430
# LONGITUD             373430
# CIUDAD               373430
# ORIGEN_DEL_PEDIDO         3
# NUM_PEDIDO                0
# METODO_DE_PAGO            0
# MONTO_TOTAL               0
# DESCUENTO                 0
# FECHAHORA_CREA            0
# MEMBRESIA                 0
# MENU                      0
# dtype: int64

# %%
# TOP NEGOCIO_N
plt.pie(df.NEGOCIO_N.value_counts()[:15], labels = df.NEGOCIO_N.unique()[:15])
plt.show()
